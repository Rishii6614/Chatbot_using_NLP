# %%
pip install nltk scikit-learn streamlit
# Out:
# ...
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/3d/b0/031933cb253d757dfc8791707d413ce90ab52ec7fb4524ef955070136d31/streamlit-1.43.2-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/aa/f3/0b6ced594e51cc95d8c1fc1640d3623770d01e4969d29c0bd09945fafefa/altair-5.5.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for blinker<2,>=1.0.0 from https://files.pythonhosted.org/packages/10/cb/f2ad4230dc2eb1a74edf38f1a38b9b52277f75bef262d8908e60d957e13c/blinker-1.9.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for cachetools<6,>=4.0 from https://files.pythonhosted.org/packages/72/76/20fa66124dbe6be5cafeb312ece67de6b61dd91a0247d1ea13db4ebb33c2/cachetools-5.5.2-py3-none-any.whl.metadata
# ...

# %%
import sklearn
import nltk
import random
import os
import ssl
import streamlit as st
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
ssl._create_default_https_context = ssl._create_unverified_context
nltk.data.path.append(os.path.abspath('nltk_data'))
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\22ag5\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
intents = [
    {
        'tag': 'greeting',
        'patterns': ['Hi', 'Hello', 'Hey', 'What\'s up', 'How are you'],
        'responses': ['Hi there!', 'Hello!', 'Nothing much, how about you?', 'I\'m doing great, thanks!', 'Hey! How can I help?']
    },
    {
        'tag': 'goodbye',
        'patterns': ['Bye', 'See you later', 'Goodbye', 'Take care', 'Catch you later'],
        'responses': ['Goodbye!', 'See you soon!', 'Take care!', 'Catch you later!', 'Have a great day!']
    },
    {
        'tag': 'thanks',
        'patterns': ['Thank you', 'Thanks', 'Thank you so much', 'I appreciate it'],
        'responses': ['You\'re welcome!', 'No problem!', 'Glad I could help!', 'Anytime!', 'Happy to help!']
    },
    {
        'tag': 'sorry',
        'patterns': ['Sorry', 'Apologies', 'I\'m sorry', 'My bad'],
        'responses': ['No worries!', 'It\'s okay!', 'No problem at all!', 'Don\'t worry about it!', 'All good!']
    },
    {
        'tag': 'weather',
        'patterns': ['What\'s the weather like?', 'Tell me the weather', 'How is the weather?', 'What is the forecast?'],
        'responses': ['I\'m not sure about the weather right now, check your local forecast!', 'You might want to check a weather app for the latest updates.']
    },
    {
        'tag': 'time',
        'patterns': ['What time is it?', 'Tell me the time', 'What\'s the time now?'],
        'responses': ['I don\'t have access to the time, please check your device.', 'It\'s time to do something amazing!']
    },
    {
        'tag': 'name',
        'patterns': ['What is your name?', 'Who are you?', 'Tell me your name'],
        'responses': ['I\'m your friendly chatbot!', 'I\'m Chatbot, nice to meet you!']
    },
    {
        'tag': 'help',
        'patterns': ['Can you help me?', 'I need help', 'Help me out', 'I\'m stuck'],
        'responses': ['Sure! What do you need help with?', 'I\'m here for you, how can I assist?']
    },
    {
        'tag': 'love',
        'patterns': ['I love you', 'You\'re amazing', 'I love this', 'You\'re the best'],
        'responses': ['Aw, thank you! I love you too!', 'You\'re awesome too!', 'You\'re so sweet!']
    },
    {
        'tag': 'joke',
        'patterns': ['Tell me a joke', 'Make me laugh', 'Got a joke?'],
        'responses': ['Why don\'t skeletons fight each other? They don’t have the guts!', 'Why did the scarecrow win an award? Because he was outstanding in his field!']
    },
    {
        'tag': 'sports',
        'patterns': ['What\'s the latest sports news?', 'Tell me about sports', 'How are my favorite teams doing?'],
        'responses': ['I don\'t have live sports updates right now, but you can check sports websites or apps.', 'You might want to check a sports news app for real-time updates.']
    },
    {
        'tag': 'food',
        'patterns': ['What should I eat?', 'I\'m hungry', 'Give me food suggestions'],
        'responses': ['How about a pizza?', 'Maybe some sushi?', 'A good salad is always a healthy option!']
    },
    {
        'tag': 'music',
        'patterns': ['Can you recommend some music?', 'What should I listen to?', 'Play me a song'],
        'responses': ['How about listening to some jazz?', 'Try some indie rock!', 'A bit of pop might lift your spirits!']
    },
    {
        'tag': 'location',
        'patterns': ['Where am I?', 'Where is this place?', 'Can you tell me my location?'],
        'responses': ['I cannot access your location, but I hope you find it soon!', 'Please check your GPS for more details.']
    },
    {
        'tag': 'facts',
        'patterns': ['Tell me an interesting fact', 'Share a fun fact', 'Give me a random fact'],
        'responses': ['Did you know that honey never spoils?', 'Octopuses have three hearts!', 'A group of flamingos is called a "flamboyance"!']
    },
    {
        'tag': 'quotes',
        'patterns': ['Give me a quote', 'Share a motivational quote', 'Can I get an inspiring quote?'],
        'responses': ['"The only way to do great work is to love what you do." – Steve Jobs', '"Success is not the key to happiness. Happiness is the key to success." – Albert Schweitzer']
    },
    {
        'tag': 'technology',
        'patterns': ['Tell me about the latest tech', 'What\'s new in tech?', 'Any new tech news?'],
        'responses': ['You can always check out tech websites for the latest updates.', 'There are plenty of exciting new gadgets coming out this year!']
    },
    {
        'tag': 'history',
        'patterns': ['Tell me a historical fact', 'What happened in history?', 'Give me some history trivia'],
        'responses': ['Did you know the Great Wall of China is more than 13,000 miles long?', 'The first computer was created in the 1940s!']
    },
    {
        'tag': 'quote_humor',
        'patterns': ['Tell me a funny quote', 'Give me a humorous quote', 'Share a hilarious quote'],
        'responses': ['"I am writing a book. I’ve got the page numbers done." – Steven Wright', '"I’m on a seafood diet. I see food and I eat it."']
    },
    {
        'tag': 'movie',
        'patterns': ['Tell me about movies', 'What movies should I watch?', 'Give me a movie recommendation'],
        'responses': ['You should check out the latest sci-fi movies!', 'How about a classic drama?', 'A comedy movie would be a great choice!']
    },
    {
        'tag': 'work',
        'patterns': ['I don’t feel motivated at work', 'I need to focus', 'I have a lot of work to do'],
        'responses': ['Take a break and clear your mind.', 'It’s all about taking one step at a time. You’ve got this!']
    },
    {
        'tag': 'study',
        'patterns': ['I need to study', 'Can you help me with studying?', 'What should I study today?'],
        'responses': ['Focus on the subject that challenges you the most!', 'Make sure to take regular breaks while studying!']
    },
    {
        'tag': 'birthday',
        'patterns': ['Happy Birthday!', 'It\'s my birthday today!', 'Today is my special day'],
        'responses': ['Happy Birthday! Have a wonderful day!', 'Wishing you all the best on your birthday!', 'Enjoy your special day!']
    },
    {
        'tag': 'motivation',
        'patterns': ['I need some motivation', 'Encourage me', 'Give me some motivation'],
        'responses': ['You can do it! Keep pushing!', 'Success is the result of perseverance and hard work!', 'Stay positive, your effort will pay off!']
    },
    {
        'tag': 'sleep',
        'patterns': ['I\'m so tired', 'I need sleep', 'Can you help me sleep?'],
        'responses': ['Try to relax and clear your mind before bed.', 'Sleep is important! Get some rest and recharge.']
    },
    {
        'tag': 'health',
        'patterns': ['How do I stay healthy?', 'Tell me health tips', 'What should I eat for better health?'],
        'responses': ['Stay hydrated, exercise regularly, and eat balanced meals!', 'A good sleep routine also helps with your overall health!']
    },
    {
        'tag': 'shopping',
        'patterns': ['What should I buy?', 'Give me shopping suggestions', 'What\'s trending right now?'],
        'responses': ['Try some cool tech gadgets!', 'Fashion trends are always fun to explore!', 'How about some new books to read?']
    },
    {
        'tag': 'exercise',
        'patterns': ['How do I start exercising?', 'Tell me some exercises to do', 'I need workout suggestions'],
        'responses': ['Start with basic stretches and work your way up!', 'Try a mix of cardio and strength exercises!', 'Yoga can also help with flexibility and relaxation.']
    },
    {
        'tag': 'celebration',
        'patterns': ['Let\'s celebrate!', 'It\'s time for a celebration!', 'I want to celebrate something'],
        'responses': ['Sounds great! What are we celebrating?', 'Celebration time! Let\'s make it special!']
    },
    {
        'tag': 'new_year',
        'patterns': ['Happy New Year!', 'New Year wishes', 'What\'s your New Year resolution?'],
        'responses': ['Happy New Year! May your year be full of success!', 'Cheers to a new year and new opportunities!']
    },
    {
        'tag': 'travel',
        'patterns': ['Tell me about travel destinations', 'Where should I travel?', 'Any travel tips?'],
        'responses': ['You should check out exotic beaches!', 'There are some amazing historical cities to explore!', 'Traveling can be an incredible experience. Be sure to plan ahead!']
    },
    {
        'tag': 'vacation',
        'patterns': ['I need a vacation', 'Tell me about vacation spots', 'I want to go on a holiday'],
        'responses': ['How about a beach destination for relaxation?', 'Explore some beautiful mountains or hiking trails for your vacation!']
    },
    {
        'tag': 'learn',
        'patterns': ['I want to learn something new', 'Teach me something', 'I\'m curious about something'],
        'responses': ['Learning never stops! What would you like to know?', 'The world is full of amazing things to learn, just ask!']
    },
    {
        'tag': 'holiday',
        'patterns': ['Is today a holiday?', 'What holiday is it today?', 'Tell me about holidays'],
        'responses': ['Check the calendar for today’s special holidays!', 'It’s always fun to celebrate holidays!']
    },
    {
        'tag': 'confused',
        'patterns': ['I don’t know what to do', 'I’m confused', 'Can you help me?'],
        'responses': ['Take a deep breath! Let’s work through this together.', 'It’s okay, let’s sort this out step by step!']
    },
    {
        'tag': 'questions',
        'patterns': ['Ask me something', 'Can you quiz me?', 'I have a question for you'],
        'responses': ['Here’s a fun question: What’s the largest animal on Earth?', 'Let’s do a quiz! What is the capital of France?']
    },
]
